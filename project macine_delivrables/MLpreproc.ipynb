# %%
import pandas as pd
df = pd.read_csv("origin_merged-18-23.csv")
# Out:
#                                   Details Product  Odometer  Distance  \
# 0     Jaguar XJL Portfolio V6 D Limousine  Diesel   66089.0    4140.0
# 1                Vauxhall CORSA  CDTI Car  Diesel    6075.0    1958.0
# 2      Vauxhall Mokka 4x4 Utility Vehicle  Diesel   21650.0    5060.0
# 3                     Peugeot 308 Car Car  Diesel   64740.0   42009.0
# 4         Peugeot Expert Combi 9 seat MPV  Diesel   19023.0    8934.0
# ...                                   ...     ...       ...       ...
# 3546                           3 Axle RCV  Diesel       NaN   15069.0
# 3547        Dennis Eagle Elite 3 Axle Bin  Diesel       NaN    2174.0
# 3548        Dennis Eagle Elite 3 Axle Bin  Diesel       NaN    3212.0
# 3549           Mercedes Econic 3 Axle Bin  Diesel       NaN    8226.0
# 3550           Mercedes Econic 3 Axle Bin  Diesel       NaN    9358.0
#
#             Unit    MPG    ID    Litres
# 0          Miles  24.10     2       NaN
# 1          Miles  45.10     3       NaN
# ...

# %%
#drop odometer column
df = df.drop(columns=['Odometer'])
df
# Out:
#                                   Details Product  Distance        Unit  \
# 0     Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0       Miles
# 1                Vauxhall CORSA  CDTI Car  Diesel    1958.0       Miles
# 2      Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0       Miles
# 3                     Peugeot 308 Car Car  Diesel   42009.0       Miles
# 4         Peugeot Expert Combi 9 seat MPV  Diesel    8934.0       Miles
# ...                                   ...     ...       ...         ...
# 3546                           3 Axle RCV  Diesel   15069.0  Kilometres
# 3547        Dennis Eagle Elite 3 Axle Bin  Diesel    2174.0  Kilometres
# 3548        Dennis Eagle Elite 3 Axle Bin  Diesel    3212.0  Kilometres
# 3549           Mercedes Econic 3 Axle Bin  Diesel    8226.0  Kilometres
# 3550           Mercedes Econic 3 Axle Bin  Diesel    9358.0  Kilometres
#
#         MPG    ID    Litres
# 0     24.10     2       NaN
# 1     45.10     3       NaN
# ...

# %%
#drop id
df = df.drop(columns=['ID'])
# Out:
#                                   Details Product  Distance        Unit  \
# 0     Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0       Miles
# 1                Vauxhall CORSA  CDTI Car  Diesel    1958.0       Miles
# 2      Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0       Miles
# 3                     Peugeot 308 Car Car  Diesel   42009.0       Miles
# 4         Peugeot Expert Combi 9 seat MPV  Diesel    8934.0       Miles
# ...                                   ...     ...       ...         ...
# 3546                           3 Axle RCV  Diesel   15069.0  Kilometres
# 3547        Dennis Eagle Elite 3 Axle Bin  Diesel    2174.0  Kilometres
# 3548        Dennis Eagle Elite 3 Axle Bin  Diesel    3212.0  Kilometres
# 3549           Mercedes Econic 3 Axle Bin  Diesel    8226.0  Kilometres
# 3550           Mercedes Econic 3 Axle Bin  Diesel    9358.0  Kilometres
#
#         MPG    Litres
# 0     24.10       NaN
# 1     45.10       NaN
# 2     43.73       NaN
# ...

# %%
import pandas as pd
df2 = pd.read_csv("Cars export 2025-05-27 13-46-18.csv")
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0                I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1               Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2           2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3       Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4             Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 97707         Fiesta  2017  10447    Automatic     8337   Petrol  145  54.3
# 97708       3 Series  2014  14995       Manual    25372   Diesel   30  61.4
# 97709         Fiesta  2017   8950       Manual    19910   Petrol  125  54.3
# 97710          Astra  2017  10700    Automatic    24468   Petrol  125  50.4
# 97711    Grandland X  2019  15798       Manual    10586   Diesel  150  48.7
#
#        engineSize Manufacturer
# ...

# %%
# add the two columns model and manufactorer together
df2['Model'] = df2['Manufacturer'] + ' ' + df2['model']
df2
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0                I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1               Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2           2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3       Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4             Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 97707         Fiesta  2017  10447    Automatic     8337   Petrol  145  54.3
# 97708       3 Series  2014  14995       Manual    25372   Diesel   30  61.4
# 97709         Fiesta  2017   8950       Manual    19910   Petrol  125  54.3
# 97710          Astra  2017  10700    Automatic    24468   Petrol  125  50.4
# 97711    Grandland X  2019  15798       Manual    10586   Diesel  150  48.7
#
#        engineSize Manufacturer                  Model
# ...

# %%
#drop model
df2 = df2.drop(columns=['model'])
df2
# Out:
#        year  price transmission  mileage fuelType  tax   mpg  engineSize  \
# 0      2017   7495       Manual    11630   Petrol  145  60.1         1.0
# 1      2017  10989       Manual     9200   Petrol  145  58.9         1.0
# 2      2019  27990    Semi-Auto     1614   Diesel  145  49.6         2.0
# 3      2017  12495       Manual    30960   Diesel  150  62.8         2.0
# 4      2017   7999       Manual    19353   Petrol  125  54.3         1.2
# ...     ...    ...          ...      ...      ...  ...   ...         ...
# 97707  2017  10447    Automatic     8337   Petrol  145  54.3         1.0
# 97708  2014  14995       Manual    25372   Diesel   30  61.4         2.0
# 97709  2017   8950       Manual    19910   Petrol  125  54.3         1.2
# 97710  2017  10700    Automatic    24468   Petrol  125  50.4         1.4
# 97711  2019  15798       Manual    10586   Diesel  150  48.7         1.5
#
#       Manufacturer                  Model
# 0           hyundi            hyundi  I10
# ...

# %%
#  drop tax
df2 = df2.drop(columns=['tax'])
df2
# Out:
#        year  price transmission  mileage fuelType   mpg  engineSize  \
# 0      2017   7495       Manual    11630   Petrol  60.1         1.0
# 1      2017  10989       Manual     9200   Petrol  58.9         1.0
# 2      2019  27990    Semi-Auto     1614   Diesel  49.6         2.0
# 3      2017  12495       Manual    30960   Diesel  62.8         2.0
# 4      2017   7999       Manual    19353   Petrol  54.3         1.2
# ...     ...    ...          ...      ...      ...   ...         ...
# 97707  2017  10447    Automatic     8337   Petrol  54.3         1.0
# 97708  2014  14995       Manual    25372   Diesel  61.4         2.0
# 97709  2017   8950       Manual    19910   Petrol  54.3         1.2
# 97710  2017  10700    Automatic    24468   Petrol  50.4         1.4
# 97711  2019  15798       Manual    10586   Diesel  48.7         1.5
#
#       Manufacturer                  Model
# 0           hyundi            hyundi  I10
# 1       volkswagen       volkswagen  Polo
# ...

# %%
#drop manfacturer
df2 = df2.drop(columns=['Manufacturer'])
df2
# Out:
#        year  price transmission  mileage fuelType   mpg  engineSize  \
# 0      2017   7495       Manual    11630   Petrol  60.1         1.0
# 1      2017  10989       Manual     9200   Petrol  58.9         1.0
# 2      2019  27990    Semi-Auto     1614   Diesel  49.6         2.0
# 3      2017  12495       Manual    30960   Diesel  62.8         2.0
# 4      2017   7999       Manual    19353   Petrol  54.3         1.2
# ...     ...    ...          ...      ...      ...   ...         ...
# 97707  2017  10447    Automatic     8337   Petrol  54.3         1.0
# 97708  2014  14995       Manual    25372   Diesel  61.4         2.0
# 97709  2017   8950       Manual    19910   Petrol  54.3         1.2
# 97710  2017  10700    Automatic    24468   Petrol  50.4         1.4
# 97711  2019  15798       Manual    10586   Diesel  48.7         1.5
#
#                        Model
# 0                hyundi  I10
# 1           volkswagen  Polo
# 2              BMW  2 Series
# 3        skoda  Yeti Outdoor
# ...

# %%
#drop engine size
df2 = df2.drop(columns=['engineSize'])
df2
# Out:
#        year  price transmission  mileage fuelType   mpg                  Model
# 0      2017   7495       Manual    11630   Petrol  60.1            hyundi  I10
# 1      2017  10989       Manual     9200   Petrol  58.9       volkswagen  Polo
# 2      2019  27990    Semi-Auto     1614   Diesel  49.6          BMW  2 Series
# 3      2017  12495       Manual    30960   Diesel  62.8    skoda  Yeti Outdoor
# 4      2017   7999       Manual    19353   Petrol  54.3           ford  Fiesta
# ...     ...    ...          ...      ...      ...   ...                    ...
# 97707  2017  10447    Automatic     8337   Petrol  54.3           ford  Fiesta
# 97708  2014  14995       Manual    25372   Diesel  61.4          BMW  3 Series
# 97709  2017   8950       Manual    19910   Petrol  54.3           ford  Fiesta
# 97710  2017  10700    Automatic    24468   Petrol  50.4        vauxhall  Astra
# 97711  2019  15798       Manual    10586   Diesel  48.7  vauxhall  Grandland X
#
# ...

# %%
#add model and year together
df2['Model'] = df2['Model'] + ' ' + df2['year'].astype(str)
df2
# Out:
#        year  price transmission  mileage fuelType   mpg  \
# 0      2017   7495       Manual    11630   Petrol  60.1
# 1      2017  10989       Manual     9200   Petrol  58.9
# 2      2019  27990    Semi-Auto     1614   Diesel  49.6
# 3      2017  12495       Manual    30960   Diesel  62.8
# 4      2017   7999       Manual    19353   Petrol  54.3
# ...     ...    ...          ...      ...      ...   ...
# 97707  2017  10447    Automatic     8337   Petrol  54.3
# 97708  2014  14995       Manual    25372   Diesel  61.4
# 97709  2017   8950       Manual    19910   Petrol  54.3
# 97710  2017  10700    Automatic    24468   Petrol  50.4
# 97711  2019  15798       Manual    10586   Diesel  48.7
#
#                             Model
# 0                hyundi  I10 2017
# 1           volkswagen  Polo 2017
# 2              BMW  2 Series 2019
# 3        skoda  Yeti Outdoor 2017
# 4               ford  Fiesta 2017
# ...                           ...
# 97707           ford  Fiesta 2017
# ...

# %%
# drop year
df2 = df2.drop(columns=['year'])
df2
# Out:
#        price transmission  mileage fuelType   mpg                       Model
# 0       7495       Manual    11630   Petrol  60.1            hyundi  I10 2017
# 1      10989       Manual     9200   Petrol  58.9       volkswagen  Polo 2017
# 2      27990    Semi-Auto     1614   Diesel  49.6          BMW  2 Series 2019
# 3      12495       Manual    30960   Diesel  62.8    skoda  Yeti Outdoor 2017
# 4       7999       Manual    19353   Petrol  54.3           ford  Fiesta 2017
# ...      ...          ...      ...      ...   ...                         ...
# 97707  10447    Automatic     8337   Petrol  54.3           ford  Fiesta 2017
# 97708  14995       Manual    25372   Diesel  61.4          BMW  3 Series 2014
# 97709   8950       Manual    19910   Petrol  54.3           ford  Fiesta 2017
# 97710  10700    Automatic    24468   Petrol  50.4        vauxhall  Astra 2017
# 97711  15798       Manual    10586   Diesel  48.7  vauxhall  Grandland X 2019
#
# [97712 rows x 6 columns]

# %%
#drop price
df2 = df2.drop(columns=['price'])
df2
# Out:
#       transmission  mileage fuelType   mpg                       Model
# 0           Manual    11630   Petrol  60.1            hyundi  I10 2017
# 1           Manual     9200   Petrol  58.9       volkswagen  Polo 2017
# 2        Semi-Auto     1614   Diesel  49.6          BMW  2 Series 2019
# 3           Manual    30960   Diesel  62.8    skoda  Yeti Outdoor 2017
# 4           Manual    19353   Petrol  54.3           ford  Fiesta 2017
# ...            ...      ...      ...   ...                         ...
# 97707    Automatic     8337   Petrol  54.3           ford  Fiesta 2017
# 97708       Manual    25372   Diesel  61.4          BMW  3 Series 2014
# 97709       Manual    19910   Petrol  54.3           ford  Fiesta 2017
# 97710    Automatic    24468   Petrol  50.4        vauxhall  Astra 2017
# 97711       Manual    10586   Diesel  48.7  vauxhall  Grandland X 2019
#
# [97712 rows x 5 columns]

# %%
#change model to details
df2 = df2.rename(columns={'Model': 'Details'})
df2
# Out:
#       transmission  mileage fuelType   mpg                     Details
# 0           Manual    11630   Petrol  60.1            hyundi  I10 2017
# 1           Manual     9200   Petrol  58.9       volkswagen  Polo 2017
# 2        Semi-Auto     1614   Diesel  49.6          BMW  2 Series 2019
# 3           Manual    30960   Diesel  62.8    skoda  Yeti Outdoor 2017
# 4           Manual    19353   Petrol  54.3           ford  Fiesta 2017
# ...            ...      ...      ...   ...                         ...
# 97707    Automatic     8337   Petrol  54.3           ford  Fiesta 2017
# 97708       Manual    25372   Diesel  61.4          BMW  3 Series 2014
# 97709       Manual    19910   Petrol  54.3           ford  Fiesta 2017
# 97710    Automatic    24468   Petrol  50.4        vauxhall  Astra 2017
# 97711       Manual    10586   Diesel  48.7  vauxhall  Grandland X 2019
#
# [97712 rows x 5 columns]

# %%
#change fueltype to Product
df2 = df2.rename(columns={'fuelType': 'Product'})
df2
# Out:
#       transmission  mileage Product   mpg                     Details
# 0           Manual    11630  Petrol  60.1            hyundi  I10 2017
# 1           Manual     9200  Petrol  58.9       volkswagen  Polo 2017
# 2        Semi-Auto     1614  Diesel  49.6          BMW  2 Series 2019
# 3           Manual    30960  Diesel  62.8    skoda  Yeti Outdoor 2017
# 4           Manual    19353  Petrol  54.3           ford  Fiesta 2017
# ...            ...      ...     ...   ...                         ...
# 97707    Automatic     8337  Petrol  54.3           ford  Fiesta 2017
# 97708       Manual    25372  Diesel  61.4          BMW  3 Series 2014
# 97709       Manual    19910  Petrol  54.3           ford  Fiesta 2017
# 97710    Automatic    24468  Petrol  50.4        vauxhall  Astra 2017
# 97711       Manual    10586  Diesel  48.7  vauxhall  Grandland X 2019
#
# [97712 rows x 5 columns]

# %%
#change mileage to Distance
df2 = df2.rename(columns={'mileage': 'Distance'})
df2
# Out:
#       transmission  Distance Product   mpg                     Details
# 0           Manual     11630  Petrol  60.1            hyundi  I10 2017
# 1           Manual      9200  Petrol  58.9       volkswagen  Polo 2017
# 2        Semi-Auto      1614  Diesel  49.6          BMW  2 Series 2019
# 3           Manual     30960  Diesel  62.8    skoda  Yeti Outdoor 2017
# 4           Manual     19353  Petrol  54.3           ford  Fiesta 2017
# ...            ...       ...     ...   ...                         ...
# 97707    Automatic      8337  Petrol  54.3           ford  Fiesta 2017
# 97708       Manual     25372  Diesel  61.4          BMW  3 Series 2014
# 97709       Manual     19910  Petrol  54.3           ford  Fiesta 2017
# 97710    Automatic     24468  Petrol  50.4        vauxhall  Astra 2017
# 97711       Manual     10586  Diesel  48.7  vauxhall  Grandland X 2019
#
# [97712 rows x 5 columns]

# %%
#drop transmission

df2 = df2.drop(columns=['transmission'])
df2
# Out:
#        Distance Product   mpg                     Details
# 0         11630  Petrol  60.1            hyundi  I10 2017
# 1          9200  Petrol  58.9       volkswagen  Polo 2017
# 2          1614  Diesel  49.6          BMW  2 Series 2019
# 3         30960  Diesel  62.8    skoda  Yeti Outdoor 2017
# 4         19353  Petrol  54.3           ford  Fiesta 2017
# ...         ...     ...   ...                         ...
# 97707      8337  Petrol  54.3           ford  Fiesta 2017
# 97708     25372  Diesel  61.4          BMW  3 Series 2014
# 97709     19910  Petrol  54.3           ford  Fiesta 2017
# 97710     24468  Petrol  50.4        vauxhall  Astra 2017
# 97711     10586  Diesel  48.7  vauxhall  Grandland X 2019
#
# [97712 rows x 4 columns]

# %%
#change mpg to MPG
df2 = df2.rename(columns={'mpg': 'MPG'})
df2
# Out:
#        Distance Product   MPG                     Details
# 0         11630  Petrol  60.1            hyundi  I10 2017
# 1          9200  Petrol  58.9       volkswagen  Polo 2017
# 2          1614  Diesel  49.6          BMW  2 Series 2019
# 3         30960  Diesel  62.8    skoda  Yeti Outdoor 2017
# 4         19353  Petrol  54.3           ford  Fiesta 2017
# ...         ...     ...   ...                         ...
# 97707      8337  Petrol  54.3           ford  Fiesta 2017
# 97708     25372  Diesel  61.4          BMW  3 Series 2014
# 97709     19910  Petrol  54.3           ford  Fiesta 2017
# 97710     24468  Petrol  50.4        vauxhall  Astra 2017
# 97711     10586  Diesel  48.7  vauxhall  Grandland X 2019
#
# [97712 rows x 4 columns]

# %%
desired_order = df.columns.tolist()

# %%
df2 = df2[['Details', 'Product','Distance' ,'MPG']]
df2
# Out:
#                           Details Product  Distance   MPG
# 0                hyundi  I10 2017  Petrol     11630  60.1
# 1           volkswagen  Polo 2017  Petrol      9200  58.9
# 2              BMW  2 Series 2019  Diesel      1614  49.6
# 3        skoda  Yeti Outdoor 2017  Diesel     30960  62.8
# 4               ford  Fiesta 2017  Petrol     19353  54.3
# ...                           ...     ...       ...   ...
# 97707           ford  Fiesta 2017  Petrol      8337  54.3
# 97708          BMW  3 Series 2014  Diesel     25372  61.4
# 97709           ford  Fiesta 2017  Petrol     19910  54.3
# 97710        vauxhall  Astra 2017  Petrol     24468  50.4
# 97711  vauxhall  Grandland X 2019  Diesel     10586  48.7
#
# [97712 rows x 4 columns]

# %%
df
# Out:
#                                   Details Product  Distance        Unit  \
# 0     Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0       Miles
# 1                Vauxhall CORSA  CDTI Car  Diesel    1958.0       Miles
# 2      Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0       Miles
# 3                     Peugeot 308 Car Car  Diesel   42009.0       Miles
# 4         Peugeot Expert Combi 9 seat MPV  Diesel    8934.0       Miles
# ...                                   ...     ...       ...         ...
# 3546                           3 Axle RCV  Diesel   15069.0  Kilometres
# 3547        Dennis Eagle Elite 3 Axle Bin  Diesel    2174.0  Kilometres
# 3548        Dennis Eagle Elite 3 Axle Bin  Diesel    3212.0  Kilometres
# 3549           Mercedes Econic 3 Axle Bin  Diesel    8226.0  Kilometres
# 3550           Mercedes Econic 3 Axle Bin  Diesel    9358.0  Kilometres
#
#         MPG    Litres
# 0     24.10       NaN
# 1     45.10       NaN
# 2     43.73       NaN
# ...

# %%
#concat df and df2
df_concat = pd.concat([df, df2])
df_concat
# Out:
#                                    Details Product  Distance   Unit    MPG  \
# 0      Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                 Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2       Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                      Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4          Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                    ...     ...       ...    ...    ...
# 97707                    ford  Fiesta 2017  Petrol    8337.0    NaN  54.30
# 97708                   BMW  3 Series 2014  Diesel   25372.0    NaN  61.40
# 97709                    ford  Fiesta 2017  Petrol   19910.0    NaN  54.30
# 97710                 vauxhall  Astra 2017  Petrol   24468.0    NaN  50.40
# 97711           vauxhall  Grandland X 2019  Diesel   10586.0    NaN  48.70
#
#        Litres
# 0         NaN
# 1         NaN
# 2         NaN
# ...

# %%
#put the null values in unit wil MILES
df_concat['Unit'] = df_concat['Unit'].fillna('Miles')
df_concat
# Out:
#                                    Details Product  Distance   Unit    MPG  \
# 0      Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                 Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2       Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                      Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4          Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                    ...     ...       ...    ...    ...
# 97707                    ford  Fiesta 2017  Petrol    8337.0  Miles  54.30
# 97708                   BMW  3 Series 2014  Diesel   25372.0  Miles  61.40
# 97709                    ford  Fiesta 2017  Petrol   19910.0  Miles  54.30
# 97710                 vauxhall  Astra 2017  Petrol   24468.0  Miles  50.40
# 97711           vauxhall  Grandland X 2019  Diesel   10586.0  Miles  48.70
#
#        Litres
# 0         NaN
# 1         NaN
# 2         NaN
# ...

# %%
#show the rows that has Kilometer
ddf=df_concat[df_concat['Unit'] == 'Kilometres']
ddf
# Out:
#                                Details Product  Distance        Unit   MPG  \
# 643   Fuso Canter 7C15 HEV Tipper 7.5t  Diesel    6405.0  Kilometres  6.85
# 651         Mercedes Econic 4 Axle Bin  Diesel    8279.0  Kilometres  1.91
# 652        Mercedes  Econic 3 Axle Bin  Diesel   19522.0  Kilometres  3.47
# 653         Mercedes Econic 3 Axle Bin  Diesel   11951.0  Kilometres  2.81
# 654         Mercedes Econic 3 Axle Bin  Diesel   13593.0  Kilometres  2.74
# ...                                ...     ...       ...         ...   ...
# 3546                        3 Axle RCV  Diesel   15069.0  Kilometres  2.74
# 3547     Dennis Eagle Elite 3 Axle Bin  Diesel    2174.0  Kilometres  3.59
# 3548     Dennis Eagle Elite 3 Axle Bin  Diesel    3212.0  Kilometres  1.97
# 3549        Mercedes Econic 3 Axle Bin  Diesel    8226.0  Kilometres  2.48
# 3550        Mercedes Econic 3 Axle Bin  Diesel    9358.0  Kilometres  2.18
#
#         Litres
# 643        NaN
# 651        NaN
# 652        NaN
# ...

# %%
km_to_miles = 0.621371

# Select rows by index range AND where unit is Kilometer
condition = (df_concat.index >= 643) & (df_concat.index <= 3550) & (df_concat['Unit'] == 'Kilometres')

# Convert Distance only for those rows
df_concat.loc[condition, 'Distance'] = df_concat.loc[condition, 'Distance'] * km_to_miles

# Update the unit to 'Miles' in those rows
df_concat.loc[condition, 'unit'] = 'Miles'
df_concat
# Out:
#                                    Details Product  Distance   Unit    MPG  \
# 0      Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                 Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2       Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                      Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4          Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                    ...     ...       ...    ...    ...
# 97707                    ford  Fiesta 2017  Petrol    8337.0  Miles  54.30
# 97708                   BMW  3 Series 2014  Diesel   25372.0  Miles  61.40
# 97709                    ford  Fiesta 2017  Petrol   19910.0  Miles  54.30
# 97710                 vauxhall  Astra 2017  Petrol   24468.0  Miles  50.40
# 97711           vauxhall  Grandland X 2019  Diesel   10586.0  Miles  48.70
#
#        Litres unit
# 0         NaN  NaN
# 1         NaN  NaN
# ...

# %%
#print the row 3550
print(df_concat.loc[3550])
# Out:
#                          Details Product      Distance        Unit    MPG  \
# 3550  Mercedes Econic 3 Axle Bin  Diesel   5814.789818  Kilometres   2.18
# 3550            ford  B-MAX 2015  Petrol  28115.000000       Miles  55.40
#
#         Litres   unit
# 3550  12152.04  Miles
# 3550       NaN    NaN

# %%
print(df_concat.index.duplicated().sum())
# Out:
# 3551

# %%
#print duplicates
print(df_concat[df_concat.index.duplicated(keep=False)])
# Out:
#                                   Details Product  Distance   Unit    MPG  \
# 0     Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2      Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                     Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4         Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                   ...     ...       ...    ...    ...
# 3546                        Audi  A3 2017  Petrol   18713.0  Miles  60.10
# 3547                   BMW  5 Series 2019  Diesel   11794.0  Miles  62.80
# 3548                  skoda  Octavia 2017  Diesel   36620.0  Miles  62.80
# 3549                   merc  A Class 2019  Diesel    7301.0  Miles  56.50
# 3550                     ford  B-MAX 2015  Petrol   28115.0  Miles  55.40
#
#       Litres unit
# 0        NaN  NaN
# 1        NaN  NaN
# 2        NaN  NaN
# ...

# %%
df_concat = df_concat.reset_index(drop=True)
df_concat
# Out:
#                                     Details Product  Distance   Unit    MPG  \
# 0       Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                  Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2        Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                       Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4           Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                     ...     ...       ...    ...    ...
# 101258                    ford  Fiesta 2017  Petrol    8337.0  Miles  54.30
# 101259                   BMW  3 Series 2014  Diesel   25372.0  Miles  61.40
# 101260                    ford  Fiesta 2017  Petrol   19910.0  Miles  54.30
# 101261                 vauxhall  Astra 2017  Petrol   24468.0  Miles  50.40
# 101262           vauxhall  Grandland X 2019  Diesel   10586.0  Miles  48.70
#
#         Litres unit
# 0          NaN  NaN
# ...

# %%
df_concat
# Out:
#                                     Details Product  Distance   Unit    MPG  \
# 0       Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                  Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2        Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                       Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4           Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                     ...     ...       ...    ...    ...
# 101258                    ford  Fiesta 2017  Petrol    8337.0  Miles  54.30
# 101259                   BMW  3 Series 2014  Diesel   25372.0  Miles  61.40
# 101260                    ford  Fiesta 2017  Petrol   19910.0  Miles  54.30
# 101261                 vauxhall  Astra 2017  Petrol   24468.0  Miles  50.40
# 101262           vauxhall  Grandland X 2019  Diesel   10586.0  Miles  48.70
#
#         Litres unit
# 0          NaN  NaN
# ...

# %%
#check for  duplicated
print(df_concat.index.duplicated().sum())
# Out:
# 0

# %%
#drop unit
df_concat = df_concat.drop(columns=['unit'])
df_concat
# Out:
#                                     Details Product  Distance   Unit    MPG  \
# 0       Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                  Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2        Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                       Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4           Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                     ...     ...       ...    ...    ...
# 101258                    ford  Fiesta 2017  Petrol    8337.0  Miles  54.30
# 101259                   BMW  3 Series 2014  Diesel   25372.0  Miles  61.40
# 101260                    ford  Fiesta 2017  Petrol   19910.0  Miles  54.30
# 101261                 vauxhall  Astra 2017  Petrol   24468.0  Miles  50.40
# 101262           vauxhall  Grandland X 2019  Diesel   10586.0  Miles  48.70
#
#         Litres
# 0          NaN
# 1          NaN
# ...

# %%
#change from Kilometer to Mile in Unit
df_concat['Unit'] = df_concat['Unit'].replace('Kilometres', 'Miles')
df_concat
# Out:
#                                     Details Product  Distance   Unit    MPG  \
# 0       Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                  Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2        Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                       Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4           Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                     ...     ...       ...    ...    ...
# 101258                    ford  Fiesta 2017  Petrol    8337.0  Miles  54.30
# 101259                   BMW  3 Series 2014  Diesel   25372.0  Miles  61.40
# 101260                    ford  Fiesta 2017  Petrol   19910.0  Miles  54.30
# 101261                 vauxhall  Astra 2017  Petrol   24468.0  Miles  50.40
# 101262           vauxhall  Grandland X 2019  Diesel   10586.0  Miles  48.70
#
#         Litres
# 0          NaN
# 1          NaN
# ...

# %%
#drop litres
df_concat = df_concat.drop(columns=['Litres'])
df_concat
# Out:
#                                     Details Product  Distance   Unit    MPG
# 0       Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                  Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2        Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                       Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4           Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                     ...     ...       ...    ...    ...
# 101258                    ford  Fiesta 2017  Petrol    8337.0  Miles  54.30
# 101259                   BMW  3 Series 2014  Diesel   25372.0  Miles  61.40
# 101260                    ford  Fiesta 2017  Petrol   19910.0  Miles  54.30
# 101261                 vauxhall  Astra 2017  Petrol   24468.0  Miles  50.40
# 101262           vauxhall  Grandland X 2019  Diesel   10586.0  Miles  48.70
#
# [101263 rows x 5 columns]

# %%
#check fo nulls
df_concat.isnull().sum()
# Out:
# Details     0
# Product     0
# Distance    0
# Unit        0
# MPG         0
# dtype: int64

# %% [markdown]
# # **Pre proccessing**

# %%
df_concat
# Out:
#                                     Details Product  Distance   Unit    MPG
# 0       Jaguar XJL Portfolio V6 D Limousine  Diesel    4140.0  Miles  24.10
# 1                  Vauxhall CORSA  CDTI Car  Diesel    1958.0  Miles  45.10
# 2        Vauxhall Mokka 4x4 Utility Vehicle  Diesel    5060.0  Miles  43.73
# 3                       Peugeot 308 Car Car  Diesel   42009.0  Miles  53.23
# 4           Peugeot Expert Combi 9 seat MPV  Diesel    8934.0  Miles  36.90
# ...                                     ...     ...       ...    ...    ...
# 101258                    ford  Fiesta 2017  Petrol    8337.0  Miles  54.30
# 101259                   BMW  3 Series 2014  Diesel   25372.0  Miles  61.40
# 101260                    ford  Fiesta 2017  Petrol   19910.0  Miles  54.30
# 101261                 vauxhall  Astra 2017  Petrol   24468.0  Miles  50.40
# 101262           vauxhall  Grandland X 2019  Diesel   10586.0  Miles  48.70
#
# [101263 rows x 5 columns]

# %%
#convert product to numerical
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_concat['Product'] = le.fit_transform(df_concat['Product'])
df_concat
# Out:
#                                     Details  Product  Distance   Unit    MPG
# 0       Jaguar XJL Portfolio V6 D Limousine        0    4140.0  Miles  24.10
# 1                  Vauxhall CORSA  CDTI Car        0    1958.0  Miles  45.10
# 2        Vauxhall Mokka 4x4 Utility Vehicle        0    5060.0  Miles  43.73
# 3                       Peugeot 308 Car Car        0   42009.0  Miles  53.23
# 4           Peugeot Expert Combi 9 seat MPV        0    8934.0  Miles  36.90
# ...                                     ...      ...       ...    ...    ...
# 101258                    ford  Fiesta 2017        4    8337.0  Miles  54.30
# 101259                   BMW  3 Series 2014        0   25372.0  Miles  61.40
# 101260                    ford  Fiesta 2017        4   19910.0  Miles  54.30
# 101261                 vauxhall  Astra 2017        4   24468.0  Miles  50.40
# 101262           vauxhall  Grandland X 2019        0   10586.0  Miles  48.70
#
# [101263 rows x 5 columns]

# %%
#visualize data using scatter plot
import seaborn as sns
sns.scatterplot(x='Distance', y='MPG', data=df_concat)
# Out:
# <Axes: xlabel='Distance', ylabel='MPG'>

# %%
#count negative values
df_concat[df_concat['Distance'] < 0].count()
# Out:
# Details     24
# Product     24
# Distance    24
# Unit        24
# MPG         24
# dtype: int64

# %%
#count negative values
df_concat[df_concat['MPG'] < 0].count()
# Out:
# Details     24
# Product     24
# Distance    24
# Unit        24
# MPG         24
# dtype: int64

# %%
#drop negative values of all columns

df_concat = df_concat[df_concat['Distance'] > 0]

# %%
#count row in df_concat
df_concat.shape
# Out:
# (100997, 5)

# %%
#visualize data using scatter plot
import seaborn as sns
sns.scatterplot(x='Distance', y='MPG', data=df_concat)
# Out:
# <Axes: xlabel='Distance', ylabel='MPG'>

# %%
#check outliers
Q1 = df_concat['Distance'].quantile(0.25)
Q3 = df_concat['Distance'].quantile(0.75)
IQR = Q3 - Q1

# Outliers are below Q1 - 1.5*IQR or above Q3 + 1.5*IQR
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df_concat[(df_concat['Distance'] < lower_bound) | (df_concat['Distance'] > upper_bound)]
print(outliers)
# Out:
#                                    Details  Product  Distance   Unit      MPG
# 3030    Ford Connect T240LWB Van Van Small        0  463033.0  Miles  6408.28
# 3584                     ford  Mondeo 2015        0  142000.0  Miles    68.90
# 3618                  vauxhall  Corsa 2008        0   84490.0  Miles    62.80
# 3658                   skoda  Octavia 2016        0   84360.0  Miles    62.80
# 3664                    toyota  Verso 2015        4   88412.0  Miles    43.50
# ...                                    ...      ...       ...    ...      ...
# 101092                  merc  C Class 2004        4  119000.0  Miles    34.50
# 101153                merc  GLE Class 2016        0   77456.0  Miles    42.80
# 101154                  merc  C Class 2015        0   70832.0  Miles    64.20
# 101173                    ford  Focus 2016        0   71364.0  Miles    74.30
# 101211                 volkswagen  Up 2012        4   77986.0  Miles    62.80
#
# [3948 rows x 5 columns]

# %%
#check correlation between mpg and distance
correlation = df['MPG'].corr(df['Distance'])
print("Correlation between MPG and Distance:", correlation)
# Out:
# Correlation between MPG and Distance: 0.7260110947625416

# %%
df_concat.shape
# Out:
# (100997, 5)

# %%
# Filter to keep only non-outliers

df_concat = df_concat[(df_concat['Distance'] >= lower_bound) & (df_concat['Distance'] <= upper_bound)]

# %%
df_concat.shape
# Out:
# (97049, 5)

# %%
#check correlation between mpg and distance
correlation = df['MPG'].corr(df['Distance'])
print("Correlation between MPG and Distance:", correlation)
# Out:
# Correlation between MPG and Distance: 0.7260110947625416

# %%
#visualize data using scatter plot
import seaborn as sns
sns.scatterplot(x='Distance', y='MPG', data=df_concat)
# Out:
# <Axes: xlabel='Distance', ylabel='MPG'>

# %%
df_concat
# Out:
#                                     Details  Product  Distance   Unit    MPG
# 0       Jaguar XJL Portfolio V6 D Limousine        0    4140.0  Miles  24.10
# 1                  Vauxhall CORSA  CDTI Car        0    1958.0  Miles  45.10
# 2        Vauxhall Mokka 4x4 Utility Vehicle        0    5060.0  Miles  43.73
# 3                       Peugeot 308 Car Car        0   42009.0  Miles  53.23
# 4           Peugeot Expert Combi 9 seat MPV        0    8934.0  Miles  36.90
# ...                                     ...      ...       ...    ...    ...
# 101258                    ford  Fiesta 2017        4    8337.0  Miles  54.30
# 101259                   BMW  3 Series 2014        0   25372.0  Miles  61.40
# 101260                    ford  Fiesta 2017        4   19910.0  Miles  54.30
# 101261                 vauxhall  Astra 2017        4   24468.0  Miles  50.40
# 101262           vauxhall  Grandland X 2019        0   10586.0  Miles  48.70
#
# [97049 rows x 5 columns]
